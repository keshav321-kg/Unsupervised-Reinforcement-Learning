# %% [markdown]
# # Unsupervised Reinforcement Learning
#
# Starter notebook for experimenting with this project in Google Colab.

# %%
# !git clone https://github.com/keshav321-kg/unsupervised-reinforcement-learning.git
# %cd unsupervised-reinforcement-learning

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Next steps
#
# Add your experiment code below.
